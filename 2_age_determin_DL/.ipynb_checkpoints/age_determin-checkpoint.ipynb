# %% [markdown]
# # Определение возраста покупателей
# Необходимо с помощью нейронных сетей создать модель, которая будет опредлеять возраст людей по фотографии.

# %%
import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPooling2D, AvgPool2D, GlobalAveragePooling2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet import ResNet50

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Загрузка данных

# %%
labels = pd.read_csv('/datasets/faces/labels.csv')

# %%
labels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7591 entries, 0 to 7590
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   file_name  7591 non-null   object
#  1   real_age   7591 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 118.7+ KB

# %%
labels.head(3)
# Out:
#     file_name  real_age
# 0  000000.jpg         4
# 1  000001.jpg        18
# 2  000002.jpg        80

# %%
datagen = ImageDataGenerator(rescale=1./255)
datagen_flow = datagen.flow_from_dataframe(
        dataframe=labels,
        directory='/datasets/faces/final_files/',
        x_col='file_name',
        y_col='real_age',
        target_size=(224, 224),
        batch_size=32,
        class_mode='raw',
        seed=12345)
# Out:
# Found 7591 validated image filenames.

# %% [markdown]
# ### График распределения возраста в в выборке

# %%
labels['real_age'].describe()
# Out:
# count    7591.000000
# mean       31.201159
# std        17.145060
# min         1.000000
# 25%        20.000000
# 50%        29.000000
# 75%        41.000000
# max       100.000000
# Name: real_age, dtype: float64

# %%
labels['real_age'].min()
# Out:
# 1

# %%
plt.title('Гистограмма распределения возра людей на фото')
plt.xlabel('возраст в годах')
plt.ylabel('кол-во в шт')
labels['real_age'].hist(bins=100);

# %% [markdown]
# Уточним что у нас около 0 происходит, вдруг там нулевые значения.

# %%
plt.title('Гистограмма распределения возра людей на фото в диапазоне от 0 до 10 лет')
plt.xlabel('возраст в годах')
plt.ylabel('кол-во в шт')
labels[labels['real_age'] < 11]['real_age'].hist(bins=10);

# %% [markdown]
# ### фотографии

# %%
features, target = next(datagen_flow)

# выводим 12 изображений
fig = plt.figure(figsize=(10,10))
for i in range(12):
    fig.add_subplot(4, 4, i+1)
    plt.imshow(features[i])
    plt.xticks([])
    plt.yticks([])
    plt.title(f'age:{target[i]}')
    plt.tight_layout()

# %% [markdown]
# **Вывод:**
# 1. Размер датасета датасета достаточный для выполенения задачи на предобученной модели ResNet50. Но для улучшения точности будем использовать аугментации.
# 2. В датасете возраст распределен в соотвествии возрастной пирамиды населения, кроме детей. Детей взято явно меньше Минимальный возраст 1 год, максимальный 100лет, медиана 29лет.
# 3.Для определения возраста необходимы прежде всего лица. Многие фотогорафии повернуты, наклонены лица, слишком много эмоций, плохое рарешение фото и тд.Это все ухудшит качество модели. Были бы фото более одинаковые,четкие (как на паспорт/вод.удостов) это бы улучшило качество модели(по моему мению).
# 4. Соотвественно  рекомендации  аугментации:
# rotation_range=30 - случайный поворот изображения на угол от -30 до 30 градусов.
# width_shift_range=0.2 и height_shift_range=0.2 - случайное смещение изображения по горизонтали и вертикали на 20% от ширины и высоты изображения.
# zoom_range=0.2 - случайное увеличение или уменьшение масштаба изображения на 20%.
# horizontal_flip=True и vertical_flip=True - случайное отражение изображения по горизонтали и вертикали.

# %% [markdown]
# ## Обучение модели

# %% [markdown]
# Функции для обучения модели

# %%
#######
def load_train(path):
    train_datagen = ImageDataGenerator( validation_split=0.25,rescale=1/255. ,
                                       horizontal_flip =True, 
                                       vertical_flip=True ,
                                       rotation_range=30, 
                                       width_shift_range = 0.2,
                                       height_shift_range =0.2,
                                       zoom_range=0.2
                                       )
    labels = pd.read_csv(f'{path}labels.csv')
    train_datagen_flow = train_datagen.flow_from_dataframe(  dataframe=labels,
        directory=f'{path}/final_files/',
        x_col='file_name',
        y_col='real_age',
        target_size=(224, 224),
        batch_size=32,
        class_mode='raw',
        subset='training',
        seed=12345)
   
    return train_datagen_flow 

#######
def load_test(path):
    test_datagen = ImageDataGenerator(validation_split=0.25, rescale=1/255.)
    labels = pd.read_csv(f'{path}labels.csv')

    test_datagen_flow = test_datagen.flow_from_dataframe(
        dataframe=labels,
        directory= f'{path}/final_files/',
        x_col='file_name',
        y_col='real_age',
        target_size=(224, 224),
        batch_size=32,
        class_mode='raw',
        subset='validation',
        seed=12345)
    return test_datagen_flow


def create_model(input_shape):
    optimizer = Adam(learning_rate=0.0001)


    backbone = ResNet50(input_shape=input_shape,
                    weights='imagenet', 
                    include_top=False)

    model = Sequential()
    model.add(backbone)
    model.add(GlobalAveragePooling2D())
    #один нейрон
    model.add(Dense(1, activation='relu')) 
    
    model.compile(optimizer=optimizer, loss='mse',  metrics=['mae']) 

    return model

def train_model(model, train_data, test_data, batch_size=None, epochs=10,
               steps_per_epoch=None, validation_steps=None):


    model.fit(train_data, 
              validation_data=test_data,
              batch_size=batch_size, epochs=epochs,
              steps_per_epoch=steps_per_epoch,
              validation_steps=validation_steps,
              verbose=2, shuffle=True)

    return model

# %% [markdown]
# обучение
# ```
#
# 2023-05-07 16:11:32.118669: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer.so.6
# 2023-05-07 16:11:32.324300: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer_plugin.so.6
# 2023-05-07 16:11:37.667558: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2023-05-07 16:11:38.344467: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:8b:00.0 name: Tesla V100-SXM2-32GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2023-05-07 16:11:38.344558: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2023-05-07 16:11:38.344591: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2023-05-07 16:11:38.410784: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2023-05-07 16:11:38.445383: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2023-05-07 16:11:38.770550: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2023-05-07 16:11:38.808793: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2023-05-07 16:11:38.808924: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-05-07 16:11:38.813544: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# Using TensorFlow backend.
# Found 5694 validated image filenames.
# Found 1897 validated image filenames.
# 2023-05-07 16:11:40.441161: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-05-07 16:11:40.472261: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-05-07 16:11:40.474211: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5f50d90 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-05-07 16:11:40.474246: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-05-07 16:11:40.665954: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5e8e670 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-05-07 16:11:40.665993: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla V100-SXM2-32GB, Compute Capability 7.0
# 2023-05-07 16:11:40.668483: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:8b:00.0 name: Tesla V100-SXM2-32GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2023-05-07 16:11:40.668558: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2023-05-07 16:11:40.668572: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2023-05-07 16:11:40.668606: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2023-05-07 16:11:40.668616: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2023-05-07 16:11:40.668627: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2023-05-07 16:11:40.668637: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2023-05-07 16:11:40.668645: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-05-07 16:11:40.672976: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# 2023-05-07 16:11:40.675547: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2023-05-07 16:11:44.050569: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1096] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-05-07 16:11:44.050619: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102]      0
# 2023-05-07 16:11:44.050627: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] 0:   N
# 2023-05-07 16:11:44.055248: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-05-07 16:11:44.055347: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1241] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10240 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:8b:00.0, compute capability: 7.0)
# Downloading data from https://github.com/keras-team/keras-applications/releases/download/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
#
#     8192/94765736 [..............................] - ETA: 1s
#    81920/94765736 [..............................] - ETA: 1:01
#   270336/94765736 [..............................] - ETA: 39s
#   827392/94765736 [..............................] - ETA: 18s
#  2310144/94765736 [..............................] - ETA: 8s
#  6291456/94765736 [>.............................] - ETA: 3s
# 10362880/94765736 [==>...........................] - ETA: 2s
# 14008320/94765736 [===>..........................] - ETA: 2s
# 18743296/94765736 [====>.........................] - ETA: 1s
# 22863872/94765736 [======>.......................] - ETA: 1s
# 26607616/94765736 [=======>......................] - ETA: 1s
# 29319168/94765736 [========>.....................] - ETA: 1s
# 33513472/94765736 [=========>....................] - ETA: 1s
# 37707776/94765736 [==========>...................] - ETA: 1s
# 41893888/94765736 [============>.................] - ETA: 1s
# 46096384/94765736 [=============>................] - ETA: 0s
# 50274304/94765736 [==============>...............] - ETA: 0s
# 54468608/94765736 [================>.............] - ETA: 0s
# 58662912/94765736 [=================>............] - ETA: 0s
# 62849024/94765736 [==================>...........] - ETA: 0s
# 67035136/94765736 [====================>.........] - ETA: 0s
# 69419008/94765736 [====================>.........] - ETA: 0s
# 71229440/94765736 [=====================>........] - ETA: 0s
# 75415552/94765736 [======================>.......] - ETA: 0s
# 79618048/94765736 [========================>.....] - ETA: 0s
# 83795968/94765736 [=========================>....] - ETA: 0s
# 87990272/94765736 [==========================>...] - ETA: 0s
# 92184576/94765736 [============================>.] - ETA: 0s
# 94773248/94765736 [==============================] - 2s 0us/step
# <class 'tensorflow.python.keras.engine.sequential.Sequential'>
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
#   ...
# WARNING:tensorflow:sample_weight modes were coerced from
#     to
#   ['...']
# Train for 178 steps, validate for 60 steps
# Epoch 1/10
# 2023-05-07 16:12:08.481811: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2023-05-07 16:12:10.554296: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 178/178 - 118s - loss: 285.4197 - mae: 12.4674 - val_loss: 609.3185 - val_mae: 19.6720
# Epoch 2/10
# 178/178 - 90s - loss: 130.3006 - mae: 8.6503 - val_loss: 564.1475 - val_mae: 18.6620
# Epoch 3/10
# 178/178 - 90s - loss: 117.3925 - mae: 8.2098 - val_loss: 407.4578 - val_mae: 15.2155
# Epoch 4/10
# 178/178 - 90s - loss: 103.8369 - mae: 7.7481 - val_loss: 246.4328 - val_mae: 11.9253
# Epoch 5/10
# 178/178 - 89s - loss: 94.0098 - mae: 7.3300 - val_loss: 119.3437 - val_mae: 8.1453
# Epoch 6/10
# 178/178 - 90s - loss: 85.6793 - mae: 7.0345 - val_loss: 86.2077 - val_mae: 7.2172
# Epoch 7/10
# 178/178 - 89s - loss: 79.8581 - mae: 6.8058 - val_loss: 101.9904 - val_mae: 7.7429
# Epoch 8/10
# 178/178 - 89s - loss: 73.8815 - mae: 6.5755 - val_loss: 127.6988 - val_mae: 8.3155
# Epoch 9/10
# 178/178 - 98s - loss: 67.0477 - mae: 6.2778 - val_loss: 90.7033 - val_mae: 6.9812
# Epoch 10/10
# 178/178 - 99s - loss: 64.4017 - mae: 6.1344 - val_loss: 87.2780 - val_mae: 7.0847
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 60/60 - 12s - loss: 87.2780 - mae: 7.0847
# Test MAE: 7.0847
# ```

# %% [markdown]
# ## Анализ обученной модели

# %% [markdown]
# **Вывод:** Модель обучена. Получены хороши результаты.
# mae: 7.0847
# 1. Для создания модели использовалась предобученная сеть ResNet50  с весами  из предварительно обученной модели ImageNet  backbone и голова в виде одного нейрона с активацией ReLU  т к  у нас задача  регрессии.
# 2. размер батча выбран   = 32, оптимизатор Adam с малым шагом обучения learning_rate = 0.0001 . Заморозка бэкбона не использовалась, т к у нас достаточно данных для ДОобучения модели, кол-во эпох 10, чтобы достигнуть метрику МАЕ = 7.
# 3. Метрика MAE достигнута = 7, что является отличным результатом на этих данных. Переобучение на посл эпохах уже пошло, но это не критично.
